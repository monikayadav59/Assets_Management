# %%
import pandas as pd

RootDir = "C:\\Users\\MONIKA YADAV\\Dropbox\\PC\\Desktop\\HCL TECH\\"

ITBL = pd.read_csv("C:\\Users\\MONIKA YADAV\\Dropbox\\PC\\Downloads\\ITBL (1).csv")
BUILDING = pd.read_excel(RootDir + "BUILDING SHEET.xlsx")
Userbase = pd.read_excel(RootDir + "User Base Data.xlsx")
Stock = pd.read_csv(RootDir + "STOCK.csv")

BUILDING["BUILDING"] = BUILDING["BUILDING"].str.rstrip(" ")
BUILDING["BUILDING"] = BUILDING["BUILDING"].str.upper()
ITBL["BUILDING"] = ITBL["BUILDING"].str.upper()

Userbase = Userbase.merge(BUILDING[["PROJECT CODE", "PROJECT NAME", "REPORTING MANAGER"]],
                          left_on="PROJECT", right_on="PROJECT CODE", how="left", indicator="BUILDING_USERBASE")
BUILDING = BUILDING[["BUILDING", "TOWER HEAD", "REGION", "TOWER HEAD EMAIL ID ", "FACILITY", "IP ADDRESS"]]

ITBL = ITBL.merge(BUILDING, on="BUILDING", how="left", indicator="BUILDING_ITBL")

Stock.rename(columns={"Status": "ITL Status"}, inplace=True)
Stock["ITL Status"] = Stock["ITL Status"].str.upper()

ITBL = ITBL.merge(Stock[["Hostname", "ITL Status"]], on="Hostname", how="left", indicator="STOCK_ITBL")
Userbase.rename(columns={"Hostnam": "Hostname"}, inplace=True)

# Rename the indicator column for Userbase-ITBL merge to avoid the ValueError
Userbase_ITBL_merge_indicator_name = "UserBase_ITBL"
ITBL = ITBL.merge(Userbase, on="Hostname", how="left", indicator=Userbase_ITBL_merge_indicator_name)

ITBL['NC ACTION']='-'
#for sep
ITBL.loc[(ITBL['SEP'] == 'Non Compliant') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'VDI') | (ITBL['System Type'] == 'Mobile Thin Client'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NC:SEP'
ITBL.loc[(ITBL['SEP'] == 'Not Reporting') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'VDI') | (ITBL['System Type'] == 'Mobile Thin Client'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NR:SEP'


#for DLP
ITBL.loc[(ITBL['DLP'] == 'Non Compliant') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'VDI') | (ITBL['System Type'] == 'Mobile Thin Client'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NC:DLP'
ITBL.loc[(ITBL['DLP'] == 'Not Reporting') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'VDI') | (ITBL['System Type'] == 'Mobile Thin Client'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NR:DLP'

#for HX
ITBL.loc[(ITBL['HX'] == 'Non Compliant') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NC:HX'
ITBL.loc[(ITBL['HX'] == 'Not Reporting') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NR:HX'

#for ENC
ITBL.loc[(ITBL['ENC'] == 'Non Compliant') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'VDI') | (ITBL['System Type'] == 'Mobile Thin Client') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NC:ENC'
ITBL.loc[(ITBL['ENC'] == 'Not Reporting') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'VDI') | (ITBL['System Type'] == 'Mobile Thin Client') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NR:ENC'

#for TITUS
ITBL.loc[(ITBL['TITUS'] == 'Non Compliant') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'Mobile Thin Client') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NC:TITUS'
ITBL.loc[(ITBL['TITUS'] == 'Not Reporting') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'Mobile Thin Client') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NR:TITUS'

#for CISCO
ITBL.loc[(ITBL['CISCO'] == 'Non Compliant') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'Mobile Thin Client') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NC:CISCO'
ITBL.loc[(ITBL['CISCO'] == 'Not Reporting') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'Mobile Thin Client') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NR:CISCO'

#for PATCH
ITBL.loc[(ITBL['PATCH'] == 'Non Compliant') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'Mobile Thin Client') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NC:PATCH'
ITBL.loc[(ITBL['PATCH'] == 'Not Reporting') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'Mobile Thin Client') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NR:PATCH'

#for EPM
ITBL.loc[(ITBL['EPM'] == 'Non Compliant') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'Mobile Thin Client') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NC:EPM'
ITBL.loc[(ITBL['EPM'] == 'Not Reporting') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'Mobile Thin Client') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NR:EPM'

#for WSS
ITBL.loc[(ITBL['WSS'] == 'Non Compliant') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'VDI') | (ITBL['System Type'] == 'Mobile Thin Client') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NC:WSS'
ITBL.loc[(ITBL['WSS'] == 'Not Reporting') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'VDI') | (ITBL['System Type'] == 'Mobile Thin Client') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NR:WSS'

#for BLOXONE
ITBL.loc[(ITBL['BLOXONE'] == 'Non Compliant') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'VDI') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NC:BLOXONE'
ITBL.loc[(ITBL['BLOXONE'] == 'Not Reporting') & (~((ITBL['System Type'] == 'Thin Client') | (ITBL['System Type'] == 'VDI') | (ITBL['System Type'] == 'Laptop'))), 'NC ACTION'] = ITBL['NC ACTION'] + ',NR:BLOXONE'

ITBL['NC ACTION']=ITBL['NC ACTION'].str.lstrip('-,')


#FOR SEP
ITBL["SEP REPORTING STATUS"]=" "

ITBL.loc[(ITBL['SEP'] == 'Non Compliant') | (ITBL['SEP'] == 'Compliant'), 'SEP REPORTING STATUS'] = ITBL['SEP REPORTING STATUS'] + 'Reporting'
ITBL.loc[(ITBL['SEP'] == 'Not Reporting'), 'SEP REPORTING STATUS'] = ITBL['SEP REPORTING STATUS'] + 'Not Reporting'


#FOR DLP
ITBL["DLP REPORTING STATUS"]=" "

ITBL.loc[(ITBL['DLP'] == 'Non Compliant') | (ITBL['DLP'] == 'Compliant'), 'DLP REPORTING STATUS'] = ITBL['DLP REPORTING STATUS'] + 'Reporting'
ITBL.loc[(ITBL['DLP'] == 'Not Reporting'), 'DLP REPORTING STATUS'] = ITBL['DLP REPORTING STATUS'] + 'Not Reporting'


#FOR ENC
ITBL["ENC REPORTING STATUS"]=" "

ITBL.loc[(ITBL['ENC'] == 'Non Compliant') | (ITBL['ENC'] == 'Compliant'), 'ENC REPORTING STATUS'] = ITBL['ENC REPORTING STATUS'] + 'Reporting'
ITBL.loc[(ITBL['ENC'] == 'Not Reporting'), 'ENC REPORTING STATUS'] = ITBL['ENC REPORTING STATUS'] + 'Not Reporting'


#FOR HX
ITBL["HX REPORTING STATUS"]=" "

ITBL.loc[(ITBL['HX'] == 'Non Compliant') | (ITBL['HX'] == 'Compliant'), 'HX REPORTING STATUS'] = ITBL['HX REPORTING STATUS'] + 'Reporting'
ITBL.loc[(ITBL['HX'] == 'Not Reporting'), 'HX REPORTING STATUS'] = ITBL['HX REPORTING STATUS'] + 'Not Reporting'


#FOR TITUS
ITBL["TITUS REPORTING STATUS"]=" "

ITBL.loc[(ITBL['TITUS'] == 'Non Compliant') | (ITBL['TITUS'] == 'Compliant'), 'TITUS REPORTING STATUS'] = ITBL['TITUS REPORTING STATUS'] + 'Reporting'
ITBL.loc[(ITBL['TITUS'] == 'Not Reporting'), 'TITUS REPORTING STATUS'] = ITBL['TITUS REPORTING STATUS'] + 'Not Reporting'


#FOR CISCO
ITBL["CISCO REPORTING STATUS"]=" "

ITBL.loc[(ITBL['CISCO'] == 'Non Compliant') | (ITBL['CISCO'] == 'Compliant'), 'CISCO REPORTING STATUS'] = ITBL['CISCO REPORTING STATUS'] + 'Reporting'
ITBL.loc[(ITBL['CISCO'] == 'Not Reporting'), 'CISCO REPORTING STATUS'] = ITBL['CISCO REPORTING STATUS'] + 'Not Reporting'


#FOR PATCH
ITBL["PATCH REPORTING STATUS"]=" "

ITBL.loc[(ITBL['PATCH'] == 'Non Compliant') | (ITBL['PATCH'] == 'Compliant'), 'PATCH REPORTING STATUS'] = ITBL['PATCH REPORTING STATUS'] + 'Reporting'
ITBL.loc[(ITBL['PATCH'] == 'Not Reporting'), 'PATCH REPORTING STATUS'] = ITBL['PATCH REPORTING STATUS'] + 'Not Reporting'


#FOR EPM
ITBL["EPM REPORTING STATUS"]=" "

ITBL.loc[(ITBL['EPM'] == 'Non Compliant') | (ITBL['EPM'] == 'Compliant'), 'EPM REPORTING STATUS'] = ITBL['EPM REPORTING STATUS'] + 'Reporting'
ITBL.loc[(ITBL['EPM'] == 'Not Reporting'), 'EPM REPORTING STATUS'] = ITBL['EPM REPORTING STATUS'] + 'Not Reporting'


#FOR WSS
ITBL["WSS REPORTING STATUS"]=" "

ITBL.loc[(ITBL['WSS'] == 'Non Compliant') | (ITBL['WSS'] == 'Compliant'), 'WSS REPORTING STATUS'] = ITBL['WSS REPORTING STATUS'] + 'Reporting'
ITBL.loc[(ITBL['WSS'] == 'Not Reporting'), 'WSS REPORTING STATUS'] = ITBL['WSS REPORTING STATUS'] + 'Not Reporting'


#FOR BLOXONE
ITBL["BLOXONE REPORTING STATUS"]=" "

ITBL.loc[(ITBL['BLOXONE'] == 'Non Compliant') | (ITBL['BLOXONE'] == 'Compliant'), 'BLOXONE REPORTING STATUS'] = ITBL['BLOXONE REPORTING STATUS'] + 'Reporting'
ITBL.loc[(ITBL['BLOXONE'] == 'Not Reporting'), 'BLOXONE REPORTING STATUS'] = ITBL['BLOXONE REPORTING STATUS'] + 'Not Reporting'



prefix_mapping={
    "Compliant":"Reporting",
    "Non Compliant":"Reporting",
    "Not Reporting":"Not Reporting"
}
ITBL['SEP_Status']=ITBL["SEP"].map(prefix_mapping)
ITBL['DLP_Status']=ITBL["DLP"].map(prefix_mapping)
ITBL['ENC_Status']=ITBL["ENC"].map(prefix_mapping)
ITBL['HX_Status']=ITBL["HX"].map(prefix_mapping)
ITBL['TITUS_Status']=ITBL["TITUS"].map(prefix_mapping)
ITBL['CISCO_Status']=ITBL["CISCO"].map(prefix_mapping)
ITBL['PATCH_Status']=ITBL["PATCH"].map(prefix_mapping)
ITBL['EPM_Status']=ITBL["EPM"].map(prefix_mapping)
ITBL['WSS_Status']=ITBL["WSS"].map(prefix_mapping)
ITBL['BLOXONE_Status']=ITBL["BLOXONE"].map(prefix_mapping)

ITBL['Reporting_counts'] = ITBL[["SEP","DLP","ENC","HX","TITUS","CISCO","PATCH","EPM","WSS","BLOXONE"]].eq("Compliant").sum(axis=1)
ITBL['Not Reporting/Non compliant_counts'] = ITBL[["SEP","DLP","ENC","HX","TITUS","CISCO","PATCH","EPM","WSS","BLOXONE"]].eq("Non Compliant").sum(axis=1)+ITBL[["SEP","DLP","ENC","HX","TITUS","CISCO","PATCH","EPM","WSS","BLOXONE"]].eq("Not Reporting").sum(axis=1)

#for DLP 
EXCULSION_DLP=pd.read_excel(RootDir+"EXCULSION.xlsx",sheet_name="DLP_Exculsion")
EXCULSION_DLP.rename(columns={'Exculsion':'Exclusion_DLP'},inplace=True)
ITBL=ITBL.merge(EXCULSION_DLP,on="Hostname",how="left",indicator="EXCULSION_DLP-ITBL")
ITBL.loc[(ITBL['EXCULSION_DLP-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NC:DLP,','')
ITBL.loc[(ITBL['EXCULSION_DLP-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NR:DLP,','')

#for sep
EXCULSION_SEP=pd.read_excel(RootDir+"EXCULSION.xlsx",sheet_name="SEP_Exculsion")
EXCULSION_SEP.rename(columns={'Exculsion':'Exclusion_SEP'},inplace=True)
ITBL=ITBL.merge(EXCULSION_SEP,on="Hostname",how="left",indicator="EXCULSION_SEP-ITBL")
ITBL.loc[(ITBL['EXCULSION_SEP-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NC:SEP,','')
ITBL.loc[(ITBL['EXCULSION_SEP-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NR:SEP,','')

#FOR HX
EXCULSION_HX=pd.read_excel(RootDir+"EXCULSION.xlsx",sheet_name="HX_Exculsion")
EXCULSION_HX.rename(columns={'Exculsion':'Exclusion_HX'},inplace=True)
ITBL=ITBL.merge(EXCULSION_HX,on="Hostname",how="left",indicator="EXCULSION_HX-ITBL")
ITBL.loc[(ITBL['EXCULSION_HX-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NC:HX,','')
ITBL.loc[(ITBL['EXCULSION_HX-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NR:HX,','')

#FOR ENC
EXCULSION_ENC=pd.read_excel(RootDir+"EXCULSION.xlsx",sheet_name="ENC_Exculsion")
EXCULSION_ENC.rename(columns={'Exculsion':'Exclusion_ENC'},inplace=True)
ITBL=ITBL.merge(EXCULSION_ENC,on="Hostname",how="left",indicator="EXCULSION_ENC-ITBL")
ITBL.loc[(ITBL['EXCULSION_ENC-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NC:ENC,','')
ITBL.loc[(ITBL['EXCULSION_ENC-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NR:ENC,','')

#FOR TITUS
EXCULSION_TITUS=pd.read_excel(RootDir+"EXCULSION.xlsx",sheet_name="TITUS_Exculsion")
EXCULSION_TITUS.rename(columns={'Exculsion':'Exclusion_TITUS'},inplace=True)
ITBL=ITBL.merge(EXCULSION_TITUS,on="Hostname",how="left",indicator="EXCULSION_TITUS-ITBL")
ITBL.loc[(ITBL['EXCULSION_TITUS-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NC:TITUS,','')
ITBL.loc[(ITBL['EXCULSION_TITUS-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NR:TITUS,','')

#FOR CISCO
EXCULSION_CISCO=pd.read_excel(RootDir+"EXCULSION.xlsx",sheet_name="CISCO_Exculsion")
EXCULSION_CISCO.rename(columns={'Exculsion':'Exclusion_CISCO'},inplace=True)
ITBL=ITBL.merge(EXCULSION_CISCO,on="Hostname",how="left",indicator="EXCULSION_CISCO-ITBL")
ITBL.loc[(ITBL['EXCULSION_CISCO-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NC:CISCO,','')
ITBL.loc[(ITBL['EXCULSION_CISCO-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NR:CISCO,','')

#FOR PATCH
EXCULSION_PATCH=pd.read_excel(RootDir+"EXCULSION.xlsx",sheet_name="PATCH_Exculsion")
EXCULSION_PATCH.rename(columns={'Exculsion':'Exclusion_PATCH'},inplace=True)
ITBL=ITBL.merge(EXCULSION_PATCH,on="Hostname",how="left",indicator="EXCULSION_PATCH-ITBL")
ITBL.loc[(ITBL['EXCULSION_PATCH-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NC:PATCH,','')
ITBL.loc[(ITBL['EXCULSION_PATCH-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NR:PATCH,','')

#FOR EPM
EXCULSION_EPM=pd.read_excel(RootDir+"EXCULSION.xlsx",sheet_name="EPM_Exculsion")
EXCULSION_EPM.rename(columns={'Exculsion':'Exclusion_EPM'},inplace=True)
ITBL=ITBL.merge(EXCULSION_EPM,on="Hostname",how="left",indicator="EXCULSION_EPM-ITBL")
ITBL.loc[(ITBL['EXCULSION_EPM-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NC:EPM,','')
ITBL.loc[(ITBL['EXCULSION_EPM-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NR:EPM,','')

#FOR WSS
EXCULSION_WSS=pd.read_excel(RootDir+"EXCULSION.xlsx",sheet_name="WSS_Exculsion")
EXCULSION_WSS.rename(columns={'Exculsion':'Exclusion_WSS'},inplace=True)
ITBL=ITBL.merge(EXCULSION_WSS,on="Hostname",how="left",indicator="EXCULSION_WSS-ITBL")
ITBL.loc[(ITBL['EXCULSION_WSS-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NC:WSS,','')
ITBL.loc[(ITBL['EXCULSION_WSS-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NR:WSS,','')

#FOR BLOXONE
EXCULSION_BLOXONE=pd.read_excel(RootDir+"EXCULSION.xlsx",sheet_name="BLOXONE_Exculsion")
EXCULSION_BLOXONE.rename(columns={'Exculsion':'Exclusion_BLOXONE'},inplace=True)
ITBL=ITBL.merge(EXCULSION_BLOXONE,on="Hostname",how="left",indicator="EXCULSION_BLOXONE-ITBL")
ITBL.loc[(ITBL['EXCULSION_BLOXONE-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NC:BLOXONE,','')
ITBL.loc[(ITBL['EXCULSION_BLOXONE-ITBL']=='both'),'NC ACTION']=ITBL['NC ACTION'].str.replace('NR:BLOXONE,','')



ITBL["EXCULSION_BLOXONE-ITBL"]
ITBL["EXCLUSION OF BLOXONE"]=0

ITBL.loc[(ITBL["EXCULSION_BLOXONE-ITBL"]=="both"),"EXCLUSION OF BLOXONE"]=1

# Set default value
ITBL["BLOXONE STE"] = 0

# Apply condition to set BLOXONE STE to 1
ITBL.loc[
    (
        (ITBL["System Type"] == "Thin Client") | 
        (ITBL["System Type"] == "Laptop") | 
        (ITBL["System Type"] == "VDI")
    ),
    "BLOXONE STE"
] = 1

condition = (ITBL["EXCLUSION OF BLOXONE"] == 1) & (ITBL["BLOXONE STE"] == 1)
ITBL.loc[condition, ["EXCLUSION OF BLOXONE", "BLOXONE STE"]] = [1, 0]

#ITBL["Hostname"][ITBL["EXCLUSION OF BLOXONE"]==1].count()

ITBL["Hostname"][ITBL["BLOXONE STE"]==1].count()


ITBL["EXCULSION_SEP-ITBL"]
ITBL["EXCLUSION OF SEP"]=0

ITBL.loc[(ITBL["EXCULSION_SEP-ITBL"]=="both"),"EXCLUSION OF SEP"]=1

# Set default value
ITBL["SEP STE"] = 0

# Apply condition to set SEP STE to 1
ITBL.loc[
    (
        (ITBL["System Type"] == "Thin Client") | 
        (ITBL["System Type"] == "Mobile Thin Client") | 
        (ITBL["System Type"] == "VDI")
    ),
    "SEP STE"
] = 1

condition = (ITBL["EXCLUSION OF SEP"] == 1) & (ITBL["SEP STE"] == 1)
ITBL.loc[condition, ["EXCLUSION OF SEP", "SEP STE"]] = [1, 0]

ITBL["Hostname"][ITBL["EXCLUSION OF SEP"]==1].count()

ITBL["Hostname"][ITBL["SEP STE"]==1].count()


ITBL["EXCULSION_ENC-ITBL"]
ITBL["EXCLUSION OF ENC"]=0

ITBL.loc[(ITBL["EXCULSION_ENC-ITBL"]=="both"),"EXCLUSION OF ENC"]=1

# Set default value
ITBL["ENC STE"] = 0

# Apply condition to set ENC STE to 1
ITBL.loc[
    (
        (ITBL["System Type"] == "Thin Client") | 
        (ITBL["System Type"] == "Mobile Thin Client") | 
        (ITBL["System Type"] == "Laptop") |
        (ITBL["System Type"] == "VDI")
    ),
    "ENC STE"
] = 1

condition = (ITBL["EXCLUSION OF ENC"] == 1) & (ITBL["ENC STE"] == 1)
ITBL.loc[condition, ["EXCLUSION OF ENC", "ENC STE"]] = [1, 0]

ITBL["Hostname"][ITBL["EXCLUSION OF ENC"]==1].count()

ITBL["Hostname"][ITBL["ENC STE"]==1].count()


ITBL["EXCULSION_DLP-ITBL"]
ITBL["EXCLUSION OF DLP"]=0

ITBL.loc[(ITBL["EXCULSION_DLP-ITBL"]=="both"),"EXCLUSION OF DLP"]=1

# Set default value
ITBL["DLP STE"] = 0

# Apply condition to set DLP STE to 1
ITBL.loc[
    
    (
        (ITBL["System Type"] == "Thin Client") | 
        (ITBL["System Type"] == "Mobile Thin Client") | 
        (ITBL["System Type"] == "VDI")
    ),
    "DLP STE"
] = 1

condition = (ITBL["EXCLUSION OF DLP"] == 1) & (ITBL["DLP STE"] == 1)
ITBL.loc[condition, ["EXCLUSION OF DLP", "DLP STE"]] = [1, 0]

ITBL["Hostname"][ITBL["EXCLUSION OF DLP"]==1].count()

ITBL["Hostname"][ITBL["DLP STE"]==1].count()



ITBL["EXCULSION_TITUS-ITBL"]
ITBL["EXCLUSION OF TITUS"]=0

ITBL.loc[(ITBL["EXCULSION_TITUS-ITBL"]=="both"),"EXCLUSION OF TITUS"]=1

# Set default value
ITBL["TITUS STE"] = 0

# Apply condition to set TITUS STE to 1
ITBL.loc[

    (
        (ITBL["System Type"] == "Thin Client") | 
        (ITBL["System Type"] == "Mobile Thin Client") | 
        (ITBL["System Type"] == "Laptop")
    ),
    "TITUS STE"
] = 1

condition = (ITBL["EXCLUSION OF TITUS"] == 1) & (ITBL["TITUS STE"] == 1)
ITBL.loc[condition, ["EXCLUSION OF TITUS", "TITUS STE"]] = [1, 0]

ITBL["Hostname"][ITBL["EXCLUSION OF TITUS"]==1].count()

ITBL["Hostname"][ITBL["TITUS STE"]==1].count()


ITBL["EXCULSION_HX-ITBL"]
ITBL["EXCLUSION OF HX"]=0

ITBL.loc[(ITBL["EXCULSION_HX-ITBL"]=="both"),"EXCLUSION OF HX"]=1

# Set default value
ITBL["HX STE"] = 0

# Apply condition to set HX STE to 1
ITBL.loc[
 
    (
        (ITBL["System Type"] == "Thin Client") | 
        (ITBL["System Type"] == "Laptop")
    ),
    "HX STE"
] = 1

condition = (ITBL["EXCLUSION OF HX"] == 1) & (ITBL["HX STE"] == 1)
ITBL.loc[condition, ["EXCLUSION OF HX", "HX STE"]] = [1, 0]

ITBL["Hostname"][ITBL["EXCLUSION OF HX"]==1].count()

ITBL["Hostname"][ITBL["HX STE"]==1].count()


ITBL["EXCULSION_WSS-ITBL"]
ITBL["EXCLUSION OF WSS"]=0

ITBL.loc[(ITBL["EXCULSION_WSS-ITBL"]=="both"),"EXCLUSION OF WSS"]=1

# Set default value
ITBL["WSS STE"] = 0

# Apply condition to set WSS STE to 1
ITBL.loc[
     
    (
        (ITBL["System Type"] == "Thin Client") | 
        (ITBL["System Type"] == "Mobile Thin Client") | 
        (ITBL["System Type"] == "VDI")|
        (ITBL["System Type"] == "Laptop")
    ),
    "WSS STE"
] = 1

condition = (ITBL["EXCLUSION OF WSS"] == 1) & (ITBL["WSS STE"] == 1)
ITBL.loc[condition, ["EXCLUSION OF WSS", "WSS STE"]] = [1, 0]

ITBL["Hostname"][ITBL["EXCLUSION OF WSS"]==1].count()

ITBL["Hostname"][ITBL["WSS STE"]==1].count()


ITBL["EXCULSION_PATCH-ITBL"]
ITBL["EXCLUSION OF PATCH"]=0

ITBL.loc[(ITBL["EXCULSION_PATCH-ITBL"]=="both"),"EXCLUSION OF PATCH"]=1

# Set default value
ITBL["PATCH STE"] = 0

# Apply condition to set PATCH STE to 1
ITBL.loc[
    (
        (ITBL["System Type"] == "Thin Client") | 
        (ITBL["System Type"] == "Mobile Thin Client") | 
        (ITBL["System Type"] == "Laptop")
    ),
    "PATCH STE"
] = 1

condition = (ITBL["EXCLUSION OF PATCH"] == 1) & (ITBL["PATCH STE"] == 1)
ITBL.loc[condition, ["EXCLUSION OF PATCH", "PATCH STE"]] = [1, 0]

ITBL["Hostname"][ITBL["EXCLUSION OF PATCH"]==1].count()

ITBL["Hostname"][ITBL["PATCH STE"]==1].count()


ITBL["EXCULSION_EPM-ITBL"]
ITBL["EXCLUSION OF EPM"]=0

ITBL.loc[(ITBL["EXCULSION_EPM-ITBL"]=="both"),"EXCLUSION OF EPM"]=1

# Set default value
ITBL["EPM STE"] = 0

# Apply condition to set EPMSTE to 1
ITBL.loc[
     
    (
        (ITBL["System Type"] == "Thin Client") | 
        (ITBL["System Type"] == "Mobile Thin Client") | 
        (ITBL["System Type"] == "Laptop")
    ),
    "EPM STE"
] = 1

condition = (ITBL["EXCLUSION OF EPM"] == 1) & (ITBL["EPM STE"] == 1)
ITBL.loc[condition, ["EXCLUSION OF EPM", "EPM STE"]] = [1, 0]

ITBL["Hostname"][ITBL["EXCLUSION OF EPM"]==1].count()

ITBL["Hostname"][ITBL["EPM STE"]==1].count()


ITBL["EXCULSION_CISCO-ITBL"]
ITBL["EXCLUSION OF CISCO"]=0

ITBL.loc[(ITBL["EXCULSION_CISCO-ITBL"]=="both"),"EXCLUSION OF CISCO"]=1

# Set default value
ITBL["CISCO STE"] = 0

# Apply condition to set CISCO STE to 1
ITBL.loc[
     
    ( 
        (ITBL["System Type"] == "Mobile Thin Client") | 
        (ITBL["System Type"] == "Laptop")
    ),
    "CISCO STE"
] = 1

condition = (ITBL["EXCLUSION OF CISCO"] == 1) & (ITBL["CISCO STE"] == 1)
ITBL.loc[condition, ["EXCLUSION OF CISCO", "CISCO STE"]] = [1, 0]

ITBL["Hostname"][ITBL["EXCLUSION OF CISCO"]==1].count()

ITBL["Hostname"][ITBL["CISCO STE"]==1].count()


ITBL["SEP NC"]=0
ITBL['SEP NC'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NC:SEP'))

ITBL["SEP NR"]=0
ITBL['SEP NR'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NR:SEP'))



ITBL["DLP NC"]=0
ITBL['DLP NC'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NC:DLP'))

ITBL["DLP NR"]=0
ITBL['DLP NR'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NR:DLP'))


ITBL["ENC NC"]=0
ITBL['ENC NC'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NC:ENC'))

ITBL["ENC NR"]=0
ITBL['ENC NR'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NR:ENC'))


ITBL["EPM NC"]=0
ITBL['EPM NC'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NC:EPM'))

ITBL["EPM NR"]=0
ITBL['EPM NR'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NR:EPM'))


ITBL["HX NC"]=0
ITBL['HX NC'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NC:HX'))

ITBL["HX NR"]=0
ITBL['HX NR'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NR:HX'))


ITBL["TITUS NC"]=0
ITBL['TITUS NC'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NC:TITUS'))

ITBL["TITUS NR"]=0
ITBL['TITUS NR'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NR:TITUS'))


ITBL["WSS NC"]=0
ITBL['WSS NC'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NC:WSS'))

ITBL["WSS NR"]=0
ITBL['WSS NR'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NR:WSS'))

ITBL["SEP NC"]=0
ITBL['SEP NC'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NC:SEP'))

ITBL["SEP NR"]=0
ITBL['SEP NR'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NR:SEP'))


ITBL["CISCO NC"]=0
ITBL['CISCO NC'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NC:CISCO'))

ITBL["CISCO NR"]=0
ITBL['CISCO NR'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NR:CISCO'))


ITBL["PATCH NC"]=0
ITBL['PATCH NC'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NC:PATCH'))

ITBL["PATCH NR"]=0
ITBL['PATCH NR'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NR:PATCH'))


ITBL["BLOXONE NC"]=0
ITBL['BLOXONE NC'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NC:BLOXONE'))

ITBL["BLOXONE NR"]=0
ITBL['BLOXONE NR'] = ITBL['NC ACTION'].apply(lambda x: str(x).count('NR:BLOXONE'))

# %%
ITBL
# Out:
#           Hostname            SEP            DLP            ENC  \
# 0     VDI-3MCTQVFU  Non Compliant  Not Reporting  Not Reporting
# 1      DS-Y3SKRLJQ      Compliant  Non Compliant      Compliant
# 2      DS-7LU3DY76      Compliant      Compliant      Compliant
# 3      DS-LUTM0DVF  Not Reporting  Not Reporting  Non Compliant
# 4      LP-HMNUZ3CX  Non Compliant  Not Reporting      Compliant
# ...            ...            ...            ...            ...
# 4651   DS-S7E89MLY      Compliant      Compliant  Not Reporting
# 4652  MTC-6LGZ80V7      Compliant  Non Compliant  Not Reporting
# 4653   TC-24XNAOLU  Non Compliant      Compliant  Not Reporting
# 4654   LP-YJB6PJG5  Non Compliant  Not Reporting      Compliant
# 4655   LP-SHP1HD0B      Compliant  Not Reporting  Non Compliant
#
#                  HX          TITUS          CISCO          PATCH  \
# 0     Non Compliant      Compliant      Compliant  Non Compliant
# ...

# %%
ITBL.to_csv("C:\\Users\\MONIKA YADAV\\Dropbox\\PC\\Downloads\\ITBL (1).csv", index=False)
